-- %% [markdown]
-- # Matplotlib example notebook
--
-- `IHaskell.Display` instances for the [__matplotlib__ Haskell package](https://hackage.haskell.org/package/matplotlib).
--
-- Requires the Python library [__matplotlib__](https://matplotlib.org/)

-- %%
import IHaskell.Display.Matplotlib
import Graphics.Matplotlib

-- %% [markdown]
-- Example from https://hackage.haskell.org/package/matplotlib

-- %%
contourF (\a b -> sin (a*pi/180.0) + cos (b*pi/180.0)) (-100) 100 (-200) 200 10
